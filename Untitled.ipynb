# %%
import pandas as pd
import re
import numpy as np
from scipy import stats
from datetime import timedelta
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import squarify

# %% [markdown]
# ## Challenge 1: Data Cleaning, Transformations and ETL pipeline architecture

# %%
transaction = pd.read_csv(r'test_dataset\transactions.csv')
transaction.head(20)
# Out:
#                     name             city  phone-number  \
# 0            Gary Cannon        Pricedale  339-486-5500
# 1           Brian Montes          Rosebud  336-853-9842
# 2   Christopher Todd Jr.            Llano  159-161-0094
# 3             Lynn Blake        Greenbank  174-498-3130
# 4         Jennifer Allen         S.N.P.J.  240-375-3895
# 5             Tony Price          Artesia  486-403-2838
# 6       Michelle Mullins  Preston Heights  259-622-8878
# 7           Laura Prince           Angora  535-321-6444
# 8         Aaron Williams          Wegdahl  626-546-6484
# 9           Karen Garcia         Vineland  944-661-3507
# 10         Rachel Greene           Bostic  666-582-2804
# 11          Brittany Cox          Tununak  683-268-7475
# 12      Allison Humphrey   Riverdale Park  586-293-2601
# 13      Lauren Carpenter      Pattonsburg  581-911-6622
# 14           Brandy Wood       Union Star  891-200-4254
# 15         Lindsey Lewis         Holualoa  256-420-9423
# 16         Aaron Morales      North Salem  473-386-6746
# 17      Gabrielle Morris        Splendora  745-426-6914
# 18      Christian Garcia        Tullahoma  475-440-6602
# 19          Alvin Gordon           Rogers  992-705-7350
#
#                               email                                    id  \
# 0                Gary_C@verizon.com  d37a5246-6ca3-4ade-9472-d7671becc853
# 1               Brian.M@outlook.com  65ad4511-b6fd-4cf7-8520-7f3d68776e5e
# 2          Christopher_Jr.@mail.com  45c97ee7-a932-459e-b0de-dd8160b3efe3
# 3             Blake_Lynn45@zoho.com  15abb55d-ec36-4b88-bba2-a58af8accd81
# 4          Jennifer.Allen@yahoo.com  4b166f8d-ecab-43c5-ae0f-a09beb3ea4c0
# 5           TonyPrice91@xfinity.com  614b9bb1-ee00-40a7-9b7e-a96795d1663d
# 6   Mullins_Michelle@protonmail.com  d556f557-06ea-4c6f-a712-4212eec6fca4
# 7           Prince.Laura59@zoho.com  9523ebc0-4457-4f15-b179-c0ee0011f91b
# 8                  Aaron_W@zoho.com  da841523-a03c-4cd4-a054-6e883238a424
# 9          Garcia_Karen@verizon.com  5d0fbc97-967b-4931-ba29-3d53a26ea78b
# 10             Rachel.G@xfinity.com  c8068b60-52b5-4511-a7d8-b6c7f5f9a101
# 11          BrittanyCox@hotmail.com  ad5ad4f5-e622-4ee9-87a8-ea5da0fd4f0d
# 12   Humphrey.Allison94@verizon.com  a7ded8f1-c9fa-4d75-a242-dce2cbf860ff
# 13       LaurenCarpenter80@mail.com  0979582c-ef80-4c84-a958-d4624168b7b5
# 14          Brandy_W@protonmail.com  57746a5a-59cd-403e-bdca-7ed849f0e9c2
# 15         Lindsey_Lewis@yandex.com  323d4c0d-9c6b-4ea9-9c90-cb91ceeca6de
# 16         AaronMorales@outlook.com  72204983-5987-4a1c-adcf-e7c7d31d0edb
# 17   Morris.Gabrielle21@comcast.net  03fd5d53-171b-4f3a-aeac-a40bf3ba022d
# 18     Christian_Garcia@verizon.com  44f819a6-510e-43a5-bd20-c61d49e880da
# 19                  AGordon@att.com  4000e3f6-723c-44e6-bea2-31c4a5e6c4a4
#
#     TransactionID  Amount
# 0               0    1372
# 1               1    1779
# 2               2      11
# 3               3     101
# 4               4    1318
# 5               5     300
# 6               6    1039
# 7               7      36
# 8               8     843
# 9               9    1533
# 10             10     200
# 11             11    1386
# 12             12    1522
# 13             13    1872
# 14             14     337
# 15             15    1378
# 16             16     486
# 17             17    1725
# 18             18    1658
# 19             19     296

# %%
loyalty = pd.read_csv(r'test_dataset\loyalty.csv')
loyalty.head(20)
# Out:
#                      name              city      phone-number license-plate  \
# 0             Gary Cannon       Pric#%edale      339-486-5500      BOB-0788
# 1            Brian Montes           Rosebud      336-853-9842      AXI-4190
# 2   Christopher[ Todd Jr.            Llano.   1 59#%-161-0094       LRM-754
# 3              Lynn Blake         Greenbank    174-4]98-313]0     MRW -4495
# 4          Jennifer Allen          S.N.P.J.  /240-375121-3895      HBI-2202
# 5             Tony Pric/e          [Artesia      486-403-2838       4YKJ366
# 6       Michelle Mullin[s  Presto n Heights      259-622-8878    VYF-76#%68
# 7            Laura Prince    Ang        ora      535-321-6444       3HEK811
# 8          Aaron Williams          Wegd]ahl      626-546-6484    6LMY645...
# 9           Kare[n Garcia          Vineland      944-661-3507      MIL-8989
# 10         Rachel/ Greene         Bo...stic     666-582-280 4       ELS-188
# 11          Brit/tany Cox       Tununa    k      683-268-7475      YRZ-9930
# 12    Allison Hu121mphrey    Riverdale Park      586-293-2601       SGR-361
# 13    L121auren Carpenter     Pa/]ttonsburg      581-911-6622       NGQ-678
# 14            Brandy Wood        Union Star      891-200-4254       BKB-202
# 15    Li#%n...dsey .Lewis          Holualoa      256-420-9423       3IFX742
# 16        A]aro/n Morales    N...orth Salem     473 -386-6746      VHA-8178
# 17    Gab121rielle Morris         Splendora      745-426-6914       NHV-040
# 18      Chris tian Garcia      Tullahom...a     475-440/-6602    3...ELG445
# 19    Alvin 121Gordon              Ro ]gers      992-705-7350  ]6    JWL766
#
#                                  email                                    id
# 0                 Gar#%y_C@verizon.com  d37a5246-6ca3-4ade-9472-d7671becc853
# 1                  Brian.M@outlook.com  65ad4511-b6fd-4cf7-8520-7f3d68776e5e
# 2             Christopher_Jr.@mail.com  45c97ee7-a932-459e-b0de-dd8160b3efe3
# 3            Blake_Lynn45@zoho.    com  15abb55d-ec36-4b88-bba2-a58af8accd81
# 4            Je nnifer.Allen@yahoo.com  4b166f8d-ecab-43c5-ae0f-a09beb3ea4c0
# 5              TonyPrice91@xfinity.com  614b9bb1-ee00-40a7-9b7e-a96795d1663d
# 6   M#%ullins_Michelle@protonmai]l.com  d556f557-06ea-4c6f-a712-4212eec6fca4
# 7            Prince.Laur/a59@zoho.c/om  9523ebc0-4457-4f15-b179-c0ee0011f91b
# 8                    Aaron_W @zoho.com  da841523-a03c-4cd4-a054-6e883238a424
# 9             Garcia_Karen@verizon.com  5d0fbc97-967b-4931-ba29-3d53a26ea78b
# 10               Rachel.G@x]finity.com  c8068b60-52b5-4511-a7d8-b6c7f5f9a101
# 11             BrittanyCox@hotmail.com  ad5ad4f5-e622-4ee9-87a8-ea5da0fd4f0d
# 12     Humphrey.Allison94@verizon..com  a7ded8f1-c9fa-4d75-a242-dce2cbf860ff
# 13          LaurenCarpenter80@mail.com  0979582c-ef80-4c84-a958-d4624168b7b5
# 14             Brandy_W@protonmail.com  57746a5a-59cd-403e-bdca-7ed849f0e9c2
# 15            Lindsey_Lewis@yandex.com  323d4c0d-9c6b-4ea9-9c90-cb91ceeca6de
# 16            AaronMorales@outlook.com  72204983-5987-4a1c-adcf-e7c7d31d0edb
# 17      Morris.Gabrielle21@comcast.net  03fd5d53-171b-4f3a-aeac-a40bf3ba022d
# 18    Christian_Garcia@veriz    on.com  44f819a6-510e-43a5-bd20-c61d49e880da
# 19                    AGordon@att.c]om  4000e3f6-723c-44e6-bea2-31c4a5e6c4a4

# %%
transaction.describe()
# Out:
#        TransactionID        Amount
# count    10000.00000  10000.000000
# mean      4999.50000    998.718800
# std       2886.89568    577.252406
# min          0.00000      0.000000
# 25%       2499.75000    500.000000
# 50%       4999.50000    995.000000
# 75%       7499.25000   1503.000000
# max       9999.00000   2000.000000

# %%
loyalty.describe()
# Out:
#                  name               city  phone-number license-plate  \
# count           10000              10000         10000         10000
# unique           9769               9254         10000          9999
# top     Charles Smith  Edgewater Heights  339-486-5500       FVD-796
# freq                5                  4             1             2
#
#                 email                                    id
# count           10000                                 10000
# unique           9992                                 10000
# top     MKing@aol.com  d37a5246-6ca3-4ade-9472-d7671becc853
# freq                2                                     1

# %%
#check if the id column in transaction dataset is all unique
len(transaction.id.unique())
# Out:
# 10000

# %%
#check if the id column in loyalty dataset is all unique
len(loyalty.id.unique())
# Out:
# 10000

# %%
#merge the dataset based on id column
merge = transaction.merge(loyalty, on='id', how='left', indicator=True)

#check if any transaction id not appeared in both dataset
merge[merge._merge != 'both']
# Out:
# Empty DataFrame
# Columns: [name_x, city_x, phone-number_x, email_x, id, TransactionID, Amount, name_y, city_y, phone-number_y, license-plate, email_y, _merge]
# Index: []

# %%
merge = merge[['name_x', 'city_x', 'phone-number_x', 'email_x', 'TransactionID', 'Amount', 'license-plate']]
merge.head(20)
# Out:
#                   name_x           city_x phone-number_x  \
# 0            Gary Cannon        Pricedale   339-486-5500
# 1           Brian Montes          Rosebud   336-853-9842
# 2   Christopher Todd Jr.            Llano   159-161-0094
# 3             Lynn Blake        Greenbank   174-498-3130
# 4         Jennifer Allen         S.N.P.J.   240-375-3895
# 5             Tony Price          Artesia   486-403-2838
# 6       Michelle Mullins  Preston Heights   259-622-8878
# 7           Laura Prince           Angora   535-321-6444
# 8         Aaron Williams          Wegdahl   626-546-6484
# 9           Karen Garcia         Vineland   944-661-3507
# 10         Rachel Greene           Bostic   666-582-2804
# 11          Brittany Cox          Tununak   683-268-7475
# 12      Allison Humphrey   Riverdale Park   586-293-2601
# 13      Lauren Carpenter      Pattonsburg   581-911-6622
# 14           Brandy Wood       Union Star   891-200-4254
# 15         Lindsey Lewis         Holualoa   256-420-9423
# 16         Aaron Morales      North Salem   473-386-6746
# 17      Gabrielle Morris        Splendora   745-426-6914
# 18      Christian Garcia        Tullahoma   475-440-6602
# 19          Alvin Gordon           Rogers   992-705-7350
#
#                             email_x  TransactionID  Amount license-plate
# 0                Gary_C@verizon.com              0    1372      BOB-0788
# 1               Brian.M@outlook.com              1    1779      AXI-4190
# 2          Christopher_Jr.@mail.com              2      11       LRM-754
# 3             Blake_Lynn45@zoho.com              3     101     MRW -4495
# 4          Jennifer.Allen@yahoo.com              4    1318      HBI-2202
# 5           TonyPrice91@xfinity.com              5     300       4YKJ366
# 6   Mullins_Michelle@protonmail.com              6    1039    VYF-76#%68
# 7           Prince.Laura59@zoho.com              7      36       3HEK811
# 8                  Aaron_W@zoho.com              8     843    6LMY645...
# 9          Garcia_Karen@verizon.com              9    1533      MIL-8989
# 10             Rachel.G@xfinity.com             10     200       ELS-188
# 11          BrittanyCox@hotmail.com             11    1386      YRZ-9930
# 12   Humphrey.Allison94@verizon.com             12    1522       SGR-361
# 13       LaurenCarpenter80@mail.com             13    1872       NGQ-678
# 14          Brandy_W@protonmail.com             14     337       BKB-202
# 15         Lindsey_Lewis@yandex.com             15    1378       3IFX742
# 16         AaronMorales@outlook.com             16     486      VHA-8178
# 17   Morris.Gabrielle21@comcast.net             17    1725       NHV-040
# 18     Christian_Garcia@verizon.com             18    1658    3...ELG445
# 19                  AGordon@att.com             19     296  ]6    JWL766

# %% [markdown]
# Remark: Drop the name, city, phone number and email columns from Loyalty dataset as it contains dirty data such as mixed symbols and digits in string.

# %%
merge.columns = ['name', 'city', 'phone_number', 'email', 'transaction_id', 'amount', 'license_plate']

# %%
merge.license_plate = merge.license_plate.apply(lambda x: re.sub('[^a-zA-Z0-9]', '', x))
merge.head(20)
# Out:
#                     name             city  phone_number  \
# 0            Gary Cannon        Pricedale  339-486-5500
# 1           Brian Montes          Rosebud  336-853-9842
# 2   Christopher Todd Jr.            Llano  159-161-0094
# 3             Lynn Blake        Greenbank  174-498-3130
# 4         Jennifer Allen         S.N.P.J.  240-375-3895
# 5             Tony Price          Artesia  486-403-2838
# 6       Michelle Mullins  Preston Heights  259-622-8878
# 7           Laura Prince           Angora  535-321-6444
# 8         Aaron Williams          Wegdahl  626-546-6484
# 9           Karen Garcia         Vineland  944-661-3507
# 10         Rachel Greene           Bostic  666-582-2804
# 11          Brittany Cox          Tununak  683-268-7475
# 12      Allison Humphrey   Riverdale Park  586-293-2601
# 13      Lauren Carpenter      Pattonsburg  581-911-6622
# 14           Brandy Wood       Union Star  891-200-4254
# 15         Lindsey Lewis         Holualoa  256-420-9423
# 16         Aaron Morales      North Salem  473-386-6746
# 17      Gabrielle Morris        Splendora  745-426-6914
# 18      Christian Garcia        Tullahoma  475-440-6602
# 19          Alvin Gordon           Rogers  992-705-7350
#
#                               email  transaction_id  amount license_plate
# 0                Gary_C@verizon.com               0    1372       BOB0788
# 1               Brian.M@outlook.com               1    1779       AXI4190
# 2          Christopher_Jr.@mail.com               2      11        LRM754
# 3             Blake_Lynn45@zoho.com               3     101       MRW4495
# 4          Jennifer.Allen@yahoo.com               4    1318       HBI2202
# 5           TonyPrice91@xfinity.com               5     300       4YKJ366
# 6   Mullins_Michelle@protonmail.com               6    1039       VYF7668
# 7           Prince.Laura59@zoho.com               7      36       3HEK811
# 8                  Aaron_W@zoho.com               8     843       6LMY645
# 9          Garcia_Karen@verizon.com               9    1533       MIL8989
# 10             Rachel.G@xfinity.com              10     200        ELS188
# 11          BrittanyCox@hotmail.com              11    1386       YRZ9930
# 12   Humphrey.Allison94@verizon.com              12    1522        SGR361
# 13       LaurenCarpenter80@mail.com              13    1872        NGQ678
# 14          Brandy_W@protonmail.com              14     337        BKB202
# 15         Lindsey_Lewis@yandex.com              15    1378       3IFX742
# 16         AaronMorales@outlook.com              16     486       VHA8178
# 17   Morris.Gabrielle21@comcast.net              17    1725        NHV040
# 18     Christian_Garcia@verizon.com              18    1658       3ELG445
# 19                  AGordon@att.com              19     296       6JWL766

# %%
#customer that spent 0 previously
merge[merge.amount==0]
# Out:
#                  name        city  phone_number                         email  \
# 3321   Sydney Simpson  Campanilla  491-339-3772            Sydney.S83@att.com
# 3633  Jessica Walters     Mathews  716-780-2757  JessicaWalters41@comcast.net
# 5437    Tami Thompson  Twin Lakes  401-413-2937             Tami.T@yandex.com
# 5704  Elizabeth Miles   McCaulley  340-120-3199    Elizabeth.Miles@yandex.com
# 9244     Ann Copeland  Tonganoxie  935-430-7551       Copeland_Ann@yandex.com
#
#       transaction_id  amount license_plate
# 3321            3321       0       MUG8765
# 3633            3633       0        CNB784
# 5437            5437       0       7UCE739
# 5704            5704       0       DMT9600
# 9244            9244       0    3BEE121213

# %%
city_group = merge.groupby(['city']).sum()['amount'].reset_index()
city_group.sort_values(by='amount', ascending=False)
# Out:
#               city  amount
# 5109      Oakhaven    6889
# 7328        Utuado    6294
# 2547    Gannvalley    5966
# 4930  Nickelsville    5796
# 5684    Poseyville    5547
# ...            ...     ...
# 4278       Mathews       0
# 4332     McCaulley       0
# 7274    Twin Lakes       0
# 7164    Tonganoxie       0
# 1037    Campanilla       0
#
# [7981 rows x 2 columns]

# %%
len(merge)
# Out:
# 10000

# %% [markdown]
# Both dataset is merged together by using the <i>id</i> column. <br>
# <br>
# <b>Explanation: </b>
# 1. Although there are common columns such as <i>name, city, phone number</i> and <i>email</i> existed in both dataset, but I did not consider to join the dataset using these columns as the data in <i>loyalty</i> dataset is dirty.
# 2. We can spend time to clean the symbols/digits/extra spacing from these columns but there will be no "correct" answer for the data cleaned if we do not have the master data for these customers and their transactions details.
# 3. <i>id</i> column is unique and is the primary key for both dataset.
# 4. <i>id</i> column existed in both dataset and able to merge by using the common value.
# 5. I joined the dataset by <i>id</i> column and drop the common fields from <i>loyalty</i> dataset as <i>transactions</i> dataset looks more clean and reasonable.

# %% [markdown]
# <b>Business Use Case:</b> After cleaning the dataset, group and segregate the customers into different groups using RFM model. We can then provide different business solution to different groups of customer by using different marketing strategy. Precisely target the customers can avoid wasting unnecessary marketing resources on them.

# %% [markdown]
# <b>Simple data pipeline architecture:</b>
#
# ![simple_data_pipeline.png](attachment:simple_data_pipeline.png)

# %% [markdown]
# # RFM Model
#
# Build a RFM model that segments customer into below sections:
#
# - Can’t Loose Them’
# - Champions
# - Loyal/Committed
# - Requires Attention
# - Potential
# - Promising
# - Demands Activation
#
# Remark: Since there is no transaction date for each record, we can't further analyse on the Recency (R) of the dataset. We will only analyse on the Frequency (F) and Monetary Value (M) for this dataset.

# %%
# Grouping by name
df_group = merge.groupby(['name']).agg({
    'amount': 'sum',
    'transaction_id': 'count'})
df_group
# Out:
#                 amount  transaction_id
# name
# Aaron Allen        765               1
# Aaron Brooks      1369               1
# Aaron Carson      1200               1
# Aaron Cochran      910               1
# Aaron Collier     1959               1
# ...                ...             ...
# Zachary Watson    1801               1
# Zachary Wells     1231               1
# Zoe Crawford      1649               1
# Zoe George         419               1
# Zoe Jackson        279               1
#
# [9354 rows x 2 columns]

# %%
# Renaming the columns 
df_group.rename(columns={'transaction_id': 'Frequency',
                         'amount': 'MonetaryValue'}, inplace=True)

# %%
# Printing top 5 rows and shape of the updated dataframe
print(df_group.head())
print('{:,} rows; {:,} columns'
      .format(df_group.shape[0], df_group.shape[1]))
# Out:
#                MonetaryValue  Frequency
# name
# Aaron Allen              765          1
# Aaron Brooks            1369          1
# Aaron Carson            1200          1
# Aaron Cochran            910          1
# Aaron Collier           1959          1
# 9,354 rows; 2 columns

# %%
df_group.Frequency.sort_values(ascending=False)
# Out:
# name
# Thomas Jones         6
# David Johnson        6
# David Smith          6
# James Johnson        5
# Michael Smith        5
#                     ..
# Gilbert Daugherty    1
# Gerald Walker        1
# Gerald Wagner        1
# Gerald Simmons       1
# Zoe Jackson          1
# Name: Frequency, Length: 9354, dtype: int64

# %%
# Plotting RFM distributions
plt.figure(figsize=(12,10))
# Plot distribution of F
plt.subplot(2, 1, 1); sns.histplot(df_group['Frequency'])
# Plot distribution of M
sns.displot(df_group['MonetaryValue'])
# Show the plot
plt.show()

# %%
#Calculating R and F groups
# # Create labels for Recency and Frequency
f_labels = range(1, 5)
# Assign these labels to 4 equal percentile groups 
f_groups = pd.qcut(df_group['Frequency'].rank(method='first'), q=4, labels=f_labels)
# Create new columns R and F 
df_group = df_group.assign(F = f_groups.values)
# Create labels for MonetaryValue
m_labels = range(1, 5)
# Assign these labels to three equal percentile groups 
m_groups = pd.qcut(df_group['MonetaryValue'], q=4, labels=m_labels)
# Create new column M
df_group = df_group.assign(M = m_groups.values)
df_group.head()
# Out:
#                MonetaryValue  Frequency  F  M
# name
# Aaron Allen              765          1  1  2
# Aaron Brooks            1369          1  1  3
# Aaron Carson            1200          1  1  3
# Aaron Cochran            910          1  1  2
# Aaron Collier           1959          1  1  4

# %%
def join_rfm(x): return str(str(x['F']) + str(x['M']))
df_group['RFM_Segment_Concat'] = df_group.apply(join_rfm, axis=1)
df_rfm = df_group
df_rfm.head()
# Out:
#                MonetaryValue  Frequency  F  M RFM_Segment_Concat
# name
# Aaron Allen              765          1  1  2                 12
# Aaron Brooks            1369          1  1  3                 13
# Aaron Carson            1200          1  1  3                 13
# Aaron Cochran            910          1  1  2                 12
# Aaron Collier           1959          1  1  4                 14

# %%
# Count num of unique segments
df_rfm_count_unique = df_rfm.groupby('RFM_Segment_Concat')['RFM_Segment_Concat'].nunique()
print(df_rfm_count_unique.sum())
# Calculate RFM_Score
df_rfm['RFM_Score'] = df_rfm[['F','M']].sum(axis=1)
print(df_rfm['RFM_Score'].head())
# Out:
# 16
# name
# Aaron Allen      3.0
# Aaron Brooks     4.0
# Aaron Carson     4.0
# Aaron Cochran    3.0
# Aaron Collier    5.0
# Name: RFM_Score, dtype: float64

# %%
df_rfm['RFM_Score'].unique()
# Out:
# array([3., 4., 5., 2., 8., 6., 7.])

# %%
# Define rfm_level function
def rfm_level(df):
    if df['RFM_Score'] >= 9:
        return 'Can\'t Loose Them'
    elif ((df['RFM_Score'] >= 8) and (df['RFM_Score'] < 9)):
        return 'Champions'
    elif ((df['RFM_Score'] >= 7) and (df['RFM_Score'] < 8)):
        return 'Loyal/Commited'
    elif ((df['RFM_Score'] >= 6) and (df['RFM_Score'] < 7)):
        return 'Potential'
    elif ((df['RFM_Score'] >= 5) and (df['RFM_Score'] < 6)):
        return 'Promising'
    elif ((df['RFM_Score'] >= 4) and (df['RFM_Score'] < 5)):
        return 'Requires Attention'
    else:
        return 'Demands Activation'
    
# Create a new variable RFM_Level
df_rfm['RFM_Level'] = df_rfm.apply(rfm_level, axis=1)
# Printing the header with top 15 rows 
df_rfm.head(15)
# Out:
#                 MonetaryValue  Frequency  F  M RFM_Segment_Concat  RFM_Score  \
# name
# Aaron Allen               765          1  1  2                 12        3.0
# Aaron Brooks             1369          1  1  3                 13        4.0
# Aaron Carson             1200          1  1  3                 13        4.0
# Aaron Cochran             910          1  1  2                 12        3.0
# Aaron Collier            1959          1  1  4                 14        5.0
# Aaron Combs               999          1  1  2                 12        3.0
# Aaron Cruz                286          1  1  1                 11        2.0
# Aaron Dean                164          1  1  1                 11        2.0
# Aaron Ferguson            474          1  1  1                 11        2.0
# Aaron Flynn              1645          1  1  4                 14        5.0
# Aaron Garcia              393          1  1  1                 11        2.0
# Aaron Gill               1515          1  1  3                 13        4.0
# Aaron Gray               1606          1  1  4                 14        5.0
# Aaron Hall                196          1  1  1                 11        2.0
# Aaron Jordan              212          1  1  1                 11        2.0
#
#                          RFM_Level
# name
# Aaron Allen     Demands Activation
# Aaron Brooks    Requires Attention
# Aaron Carson    Requires Attention
# Aaron Cochran   Demands Activation
# Aaron Collier            Promising
# Aaron Combs     Demands Activation
# Aaron Cruz      Demands Activation
# Aaron Dean      Demands Activation
# Aaron Ferguson  Demands Activation
# Aaron Flynn              Promising
# Aaron Garcia    Demands Activation
# Aaron Gill      Requires Attention
# Aaron Gray               Promising
# Aaron Hall      Demands Activation
# Aaron Jordan    Demands Activation

# %%
# Calculate average values for each RFM_Level, and return a size of each segment 
df_rfm_level_agg = df_rfm.groupby('RFM_Level').agg({
    'Frequency': 'mean',
    'MonetaryValue': ['mean', 'count']
}).round(1)
# Print the aggregated dataset
print(df_rfm_level_agg)
# Out:
#                    Frequency MonetaryValue
#                         mean          mean count
# RFM_Level
# Champions                1.6        2204.5   772
# Demands Activation       1.0         438.8  1842
# Loyal/Commited           1.1        1545.1  1072
# Potential                1.0        1284.0  1628
# Promising                1.0        1038.5  2222
# Requires Attention       1.0         782.6  1818

# %%
df_rfm_level_agg.columns = ['FrequencyMean','MonetaryMean', 'Count']
#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 9)
squarify.plot(sizes=df_rfm_level_agg['Count'], 
              label=['Can\'t Loose Them',
                     'Champions',
                     'Loyal/Commited',
                     'Requires Attention',
                     'Potential', 
                     'Promising', 
                     'Demands Activation'], alpha=.6 )
plt.title("RFM Segments",fontsize=18,fontweight="bold")
# plt.axis('off')
plt.show()

# %% [markdown]
# ## Challenge 2: Customer engagement

# %% [markdown]
# <b>How would you present to a customer regarding the insights derived from their dataset, in your own words?</b>
#
# After analysing the dataset by using RFM model (without R), we have segregated the customer to a few groups based on their transaction frequency and total amount. The grouping are as below: Champions, Loyal/Committed, Requires Attention, Potential, Promising and Demand Activation.
#
# For customers that segmented under Champions, they are your best customers, who bought most often and are heavy spenders. You may reward these customers as they can become early adopters for your new products and will tend to help promote your brand.
#
# For Loyal/Committed customers, they are the customers with average frequency and spent a good amount. You may offer membership or loyalty programs or recommend related products to upsell them and help them become your Champions.
#
# For Potential customers, you may start building relationsships with this customers by providing special support and offers to increase their visits.
#
# For customers that Demand Activation, send them personalized reactivation campaigns to reconnect, and offer renewals and helpful products to encourage another purchase.

# %% [markdown]
# ## Challenge 3: Scrapping , Datasourcing and Enriching data

# %% [markdown]
# <b>What is data enrichment?</b>
#
# Data enrichment is to enhance the existing dataset with more and relevant data to come out a whole new analysis.

# %%
https://www.careerbuilder.com/advice/average-salary-by-city
# Out:
#   File "<ipython-input-27-abcdd6987d6c>", line 1
#     https://www.careerbuilder.com/advice/average-salary-by-city
#           ^
# SyntaxError: invalid syntax

# %%
https://www.wikidata.org/wiki/Wikidata:Lists/US_counties

# %%
https://namecensus.com/zip-codes/
